# %% [markdown]
# ## 💻 ***Parte Prática* do Capítulo 3: EPs do Moodle**

# %% [markdown]
#  ---
#
# ### ⚠️ Aviso: 📚 Este caderno está em revisão

# %% [markdown]
# ---
#
# ### 🎯 Objetivo deste Caderno
#
# Os **Exercícios de Programação (EPs)** do Moodle (atividades VPL) fornecem *feedback* automático apenas quando acessados pela rede interna da UFABC.
#
# **Este caderno foi criado para contornar essa restrição.** Nele você pode:
# 1. Escrever sua solução.
# 2. Testar com os **mesmos casos de teste** do Moodle.
# 3. Salvar os códigos referentes às atividades VPL do Moodle.
# 4. Quando estiver na rede da universidade, clicar em **Avaliar** para obter a nota.
#
# Para mais detalhes, consulte as instruções no caderno `cap1.part5.lab.EPs.*`.
#
# ---
#
# ### 🙏 Agradecimentos
#
# Este material foi elaborado a partir dos EPs disponíveis no Moodle, criados por professores e monitores da **UFABC**.

# %%
# Inicialização rápida: salva testsuite.py neste Colab
# !pip install gdown -q && gdown '1ny6dJE9MoJ-YQvzZNPFCoPZHtfaUK2d-' -O testsuite.py --quiet && echo "✅ Ambiente pronto."

# %% [markdown]
# ---
#
# ### EP3_1 💼 Vendedor — Comissão e Metas
#
# Nesta atividade, o objetivo é calcular a comissão de um vendedor e verificar se ele atingiu a meta estipulada pela empresa baseada em seu salário fixo.
#
# * Leia **2 valores reais**:
#     1. O **Salário Fixo** ($S$) do vendedor.
#     2. O **Total de Vendas** ($V$) realizadas no mês.
# * Calcule o valor da comissão ($C$), sabendo que a empresa paga **20%** sobre o total de vendas:
#
# $$C = V \times 0.20$$
#
# * A meta estipulada é que a comissão ($C$) deve ser de **pelo menos 50%** do salário fixo ($S$). Ou seja, a meta é atingida se:
#
# $$C \ge S \times 0.50$$
#
# * Imprima o valor da comissão formatado com **duas casas decimais**.
# * Na linha seguinte, imprima se a meta foi atingida ou não.
#
# 📌 **Importante**:
#
# * **🚫 Sem Acentos:** Note que a saída para a negativa deve ser escrita como `Nao atingiu meta de vendas` (sem o til em "Nao").
# * A saída deve conter exatamente o valor e a mensagem, em linhas separadas.
#
# ---
#
# #### 📌 Exemplo
#
# | Entrada | Saída |
# | :--- | :--- |
# | 2000.00 | 700.00 |
# | 3500.00 | Nao atingiu meta de vendas |
#
# *(Explicação do exemplo acima: A comissão é $3500 \times 0.20 = 700$. A meta seria $2000 \times 0.50 = 1000$. Como $700 < 1000$, a meta não foi atingida).*
#
# ---
#
# #### 📌 Outro Exemplo
#
# | Entrada | Saída |
# | :--- | :--- |
# | 2000.00 | 1200.00 |
# | 6000.00 | Atingiu meta de vendas |
#
# *(Explicação: Comissão de $1200$ é maior que a meta de $1000$).*

# %%
#[py]#
# %%writefile EP3_1.py
# sua solução

# %%
#[py]#
# !python3 testsuite.py EP3_1.py

# %% [markdown]
# ---
#
# ### EP3_2 🧮 Equação do Segundo Grau — Bhaskara
#
# Nesta atividade, você deve criar um programa que encontre as raízes de uma equação do segundo grau na forma:
#
# $$ax^2 + bx + c = 0$$
#
# * Leia **3 valores inteiros** correspondentes aos coeficientes $a$, $b$ e $c$.
# * Calcule o discriminante ($\Delta$) utilizando a fórmula:
#
# $$\Delta = b^2 - 4ac$$
#
# * Avalie o valor de $\Delta$ para decidir a saída:
#
# 1.  **Se $\Delta < 0$**: A equação não possui raízes reais.
#     * Imprima a mensagem: `Sem Solucao real!`
#     * Na linha seguinte, imprima o valor de $\Delta$ formatado com **duas casas decimais** (ex: `Delta = -8.00`).
# 2.  **Se $\Delta = 0$**: A equação possui uma única raiz real.
#     * Imprima o texto `x = ` seguido pelo valor da raiz formatada com **duas casas decimais**.
# 3.  **Se $\Delta > 0$**: A equação possui duas raízes reais distintas.
#     * Imprima as duas raízes em linhas separadas.
#     * Utilize os prefixos `x1 = ` para a menor raiz e `x2 = ` para a maior raiz.
#     * Ambas devem estar formatadas com **duas casas decimais**.
#
# 📌 **Importante**:
#
# * **🚫 Sem Acentos:** Utilize `Solucao` e nao *Solução* na mensagem de erro.
# * Utilize a fórmula de Bhaskara para encontrar as raízes:
#
# $$x = \frac{-b \pm \sqrt{\Delta}}{2a}$$
#
# ---
#
# #### 💡 Dicas de Implementação
#
# * Pode utilizar funções prontas de bibliotecas matemáticas para calcular a raiz quadrada.
# * **Python**: `import math` e use `math.sqrt(x)`.
# * **Java**: `import java.lang.Math;` e use `Math.sqrt(x)`.
#
# ---
#
# #### 📌 Exemplos
#
# | Entrada | Saída |
# | :--- | :--- |
# | 1<br>2<br>3 | Sem Solucao real!<br>Delta = -8.00 |
# | 4<br>-4<br>1 | x = 0.50 |
# | 2<br>5<br>-4 | x1 = -3.14<br>x2 = 0.64 |
#
# *(Nota: No último exemplo, observe que x1 é a menor raiz e x2 a maior).*

# %%
#[py]#
# %%writefile EP3_2.py
# sua solução

# %%
#[py]#
# !python3 testsuite.py EP3_2.py

# %% [markdown]
# ---
#
# ### EP3_3 🎓 Conceito Final — Notas e Classificação
#
# Nesta atividade, você deve desenvolver um programa que calcule a Nota Final ($NF$) e o Conceito Final ($CF$) de um aluno, baseando-se em notas de testes e provas.
#
# * Leia **3 notas de testes** ($t_1, t_2, t_3$) lidas uma a uma.
# * Leia **2 notas de provas** ($P_1, P_2$) lidas uma a uma.
#
# Para calcular a Nota Final ($NF$), primeiro calcule a **média aritmética** dos testes ($T$):
#
# $$T = \frac{t_1 + t_2 + t_3}{3}$$
#
# Em seguida, aplique a fórmula da média ponderada:
#
# $$NF = 0.2 \times T + 0.4 \times P_1 + 0.4 \times P_2$$
#
# Defina o **Conceito Final** ($CF$) de acordo com a tabela abaixo:
#
# * **A**: se $9.0 \le NF \le 10.0$
# * **B**: se $7.5 \le NF < 9.0$
# * **C**: se $6.0 \le NF < 7.5$
# * **D**: se $5.0 \le NF < 6.0$
# * **F**: se $NF < 5.0$
#
# **Saída:**
# 1.  Imprima a **Nota Final** formatada com **duas casas decimais**.
# 2.  Na linha seguinte, imprima o **Conceito Final** (apenas a letra).
#
# ---
#
# #### 📌 Exemplo
#
# | Entrada | Saída |
# | :--- | :--- |
# | 1<br>2<br>4<br>5<br>7 | 5.27<br>D |
#
# *(Explicação do exemplo: Média dos testes $T = (1+2+4)/3 = 2.333...$ A Nota Final é $0.2(2.333) + 0.4(5) + 0.4(7) \approx 0.466 + 2.0 + 2.8 = 5.266...$, que arredondado fica 5.27. Como 5.27 está entre 5.0 e 6.0, o conceito é D).*
#
# ⚡ *Exercício adaptado do Gabriel Ângelo Sembenelli (2022).*

# %%
#[py]#
# %%writefile EP3_3.py
# sua solução

# %%
#[py]#
# !python3 testsuite.py EP3_3.py

# %% [markdown]
# ---
#
# ### EP3_4 🛸 (função) Fábrica de Discos Voadores — Funções e Lógica
#
# Nesta atividade, você deve implementar apenas a lógica de uma **função/método** para calcular o prazo de entrega de discos voadores.
#
# Uma fábrica vende discos em pacotes de três unidades. O prazo de entrega varia conforme a combinação de modelos solicitados:
#
# 1.  **3 modelos iguais** (todos os códigos idênticos): Prazo de **5 dias**.
# 2.  **2 modelos iguais e 1 diferente** (apenas dois códigos idênticos): Prazo de **15 dias**.
# 3.  **3 modelos diferentes** (todos os códigos distintos): Prazo de **30 dias**.
#
# ⚠️ **Atenção**: Você **NÃO** deve escrever o programa completo (main). Você deve apenas implementar a função que recebe os códigos e **RETORNA** o prazo (inteiro).
#
# ---
#
# #### 💻 Estrutura do Código
#
# Você deve submeter apenas o trecho de código abaixo, preenchendo a lógica interna:
#
# **Python:**
# ```python
# def obter_prazo_entrega(disco1, disco2, disco3):
#     # Implemente sua lógica aqui
#     # Retorne o valor inteiro (5, 15 ou 30)
#     return prazo
# ```
#
# ---
#
# #### ☕ Estrutura em Java
#
# ```java
# public static int obterPrazoEntrega(int disco1, int disco2, int disco3) {
#     // Seu código aqui
#     return 0; // altere o retorno
# }
#
# ```
#
# ---
#
# #### 📌 Exemplo de Execução
#
# A tabela abaixo mostra como o sistema testará sua função (ele fornece os 3 códigos e espera o retorno correto para imprimir o prazo).
#
# | Entrada | Saída |
# | --- | --- |
# | 100 | Disco1 = 100 |
# | 100 | Disco2 = 100 |
# | 200 | Disco3 = 200 |
# |  | Prazo de entrega = 15 |

# %%
#[py]#
# %%writefile EP3_4.py
# sua solução

# %%
#[py]#
# !python3 testsuite.py EP3_4.py

# %% [markdown]
# ---
#
# ### EP3_5 🌡️ Faixas de Temperatura — Condicionais e Intervalos
#
# Nesta atividade, foi encontrado um dispositivo que exibe mensagens de alerta dependendo da temperatura medida. O seu objetivo é reproduzir a lógica desse sistema.
#
# * Leia **1 valor** (pode ser número real ou inteiro) representando a temperatura $T$.
# * Classifique a temperatura e imprima a mensagem correspondente, baseando-se nas seguintes faixas:
#
# 1. **Muito Baixa**: se a temperatura for menor que -20.
#    $$T < -20$$
#
# 2. **Baixa**: se a temperatura for maior ou igual a -20 e menor que 30.
#    $$-20 \le T < 30$$
#
# 3. **Normal**: se a temperatura for maior ou igual a 30 e menor que 200.
#    $$30 \le T < 200$$
#
# 4. **Alta**: se a temperatura for maior ou igual a 200 e menor que 250.
#    $$200 \le T < 250$$
#
# 5. **Muito Alta**: se a temperatura for maior ou igual a 250.
#    $$T \ge 250$$
#
# **Entrada:**
# * Valor da temperatura.
#
# **Saída:**
# * A mensagem correspondente exatamente como escrita acima (respeitando maiúsculas e minúsculas).
#
# ---
#
# #### 📌 Exemplos
#
# | Entrada | Saída |
# | :--- | :--- |
# | -25 | Muito Baixa |
# | -20 | Baixa |
# | 10 | Baixa |
# | 30 | Normal |
# | 150.5 | Normal |
# | 200 | Alta |
# | 250 | Muito Alta |
# | 300 | Muito Alta |

# %%
#[py]#
# %%writefile EP3_5.py
# sua solução

# %%
#[py]#
# !python3 testsuite.py EP3_5.py

# %% [markdown]
# ---
#
# ### EP3_6 📅 (função) Comparação de Datas — Lógica e Condicionais
#
# Nesta atividade, você deve implementar apenas a lógica de uma **função/método** para comparar duas datas cronologicamente.
#
# A função receberá 6 valores inteiros representando duas datas:
# * **Data 1**: $d_1, m_1, a_1$ (dia, mês e ano)
# * **Data 2**: $d_2, m_2, a_2$ (dia, mês e ano)
#
# A função deve retornar um valor inteiro de acordo com as seguintes regras:
#
# 1.  Retorne **-1**: Se a **Data 1** for a mais antiga (ou seja, Data 1 vem antes da Data 2 na linha do tempo).
# 2.  Retorne **0**: Se as duas datas forem **iguais**.
# 3.  Retorne **1**: Se a **Data 2** for a mais antiga (ou seja, Data 2 vem antes da Data 1 na linha do tempo).
#
# ⚠️ **Atenção**: Você **NÃO** deve escrever o programa completo (main). Você deve apenas implementar a função que recebe os dados e **RETORNA** o valor inteiro (-1, 0 ou 1).
#
# ---
#
# #### 💻 Estrutura do Código
#
# Você deve submeter apenas o trecho de código abaixo, preenchendo a lógica interna:
#
# **Python:**
# ```python
# def comparar_datas(d1, m1, a1, d2, m2, a2):
#     # Implemente sua lógica de comparação aqui
#     # Retorne -1, 0 ou 1
#     return resultado
# ```
#
# ---
#
# #### ☕ Estrutura em Java
#
# ```java
# public static int compararDatas(int d1, int m1, int a1, int d2, int m2, int a2) {
#     // Seu código aqui
#     return 0; // altere o retorno
# }
# ```
#
# ---
#
# #### 📌 Exemplo de Execução
#
# A tabela abaixo ilustra como os dados são passados e o resultado esperado. Neste exemplo, a Data 1 (01/01/2000) é mais antiga que a Data 2 (01/01/2020), resultando em -1.
#
# | Entrada | Saída |
# | --- | --- |
# | 1 | -1 |
# | 1 |  |
# | 2000 |  |
# | 1 |  |
# | 1 |  |
# | 2020 |  |

# %%
#[py]#
# %%writefile EP3_6.py
# sua solução

# %%
#[py]#
# !python3 testsuite.py EP3_6.py

# %% [markdown]
# ---
#
# ### EP3_7 🛸 Revisão de Discos Voadores — Condicionais e Lógica
#
# Uma montadora de discos voadores enviou um comunicado sobre a necessidade de revisão em alguns modelos. Sua tarefa é criar um programa que verifique se um disco específico precisa de manutenção baseando-se no ano de produção, no motor e na distância percorrida.
#
# * Leia **3 valores inteiros**:
#     1. **Ano de produção** do disco.
#     2. Código do **Motor principal**.
#     3. **Distância percorrida** (em anos-luz).
#
# * O programa deve imprimir "SIM" ou "NAO" de acordo com a tabela de critérios abaixo:
#
# | Ano de Produção | Critério (Motor e Distância) | Requer Revisão? |
# | :--- | :--- | :--- |
# | **1901 a 2000** | Se o motor for **100** ou **101** (qualquer distância). | **SIM** |
# | **2001 a 2020** | Se a distância for **maior que 5000** anos-luz (qualquer motor). | **SIM** |
# | **2021** | Se o motor for **200** ou **201** **E** a distância for **maior que 200** anos-luz. | **SIM** |
# | **Outros casos** | Qualquer outra combinação não listada acima. | **NAO** |
#
# 📌 **Importante**:
#
# * **🚫 Sem Acentos:** A saída negativa deve ser escrita como `NAO` (sem til).
# * Atente-se aos intervalos e às conjunções (**E** / **OU**) descritas na lógica.
#
# ---
#
# #### 📌 Exemplos
#
# | Entrada (Ano, Motor, Dist.) | Saída | Explicação |
# | :--- | :--- | :--- |
# | 1995<br>100<br>50 | SIM | Ano entre 1901-2000 e motor é 100. |
# | 1995<br>300<br>50 | NAO | Ano entre 1901-2000, mas motor não é 100 nem 101. |
# | 2010<br>999<br>6000 | SIM | Ano entre 2001-2020 e distância > 5000. |
# | 2010<br>999<br>4000 | NAO | Ano entre 2001-2020, mas distância não é > 5000. |
# | 2021<br>200<br>250 | SIM | Ano 2021, motor 200 e distância > 200. |
# | 2021<br>200<br>100 | NAO | Ano 2021, motor correto, mas distância insuficiente. |
# | 2022<br>200<br>250 | NAO | Ano fora das faixas de revisão. |

# %%
#[py]#
# %%writefile EP3_7.py
# sua solução

# %%
#[py]#
# !python3 testsuite.py EP3_7.py

# %% [markdown]
# ---
#
# ### EP3_8 📍 Ponto dentro do Retângulo — Geometria e Condicionais
#
# Nesta atividade, você deve determinar se um ponto específico no plano cartesiano está localizado dentro ou fora de um retângulo pré-definido.
#
# * Leia **2 valores** (podem ser reais ou inteiros) representando as coordenadas $x$ e $y$ do ponto.
# * Verifique se o ponto $(x, y)$ está contido na área do retângulo delimitado pelos seguintes vértices (conforme a imagem original):
#     * **Canto Inferior Esquerdo:** $x = -800$ e $y = -20$
#     * **Canto Superior Direito:** $x = 22$ e $y = 35$
#
# Ou seja, para o ponto ser considerado **dentro** do retângulo, ele deve satisfazer **simultaneamente** as duas condições abaixo:
#
# 1. A coordenada $x$ deve estar entre -800 e 22 (inclusive):
#    $$-800 \le x \le 22$$
#
# 2. A coordenada $y$ deve estar entre -20 e 35 (inclusive):
#    $$-20 \le y \le 35$$
#
# **Saída:**
# * Imprima `SIM` caso o ponto esteja dentro (ou na borda) do retângulo.
# * Imprima `NAO` caso contrário.
#
# 📌 **Importante**:
#
# * **🚫 Sem Acentos:** A saída negativa deve ser escrita como `NAO` (sem til).
# * Considere as bordas como parte do retângulo (intervalo fechado).
#
# ---
#
# #### 📌 Exemplos
#
# | Entrada (x, y) | Saída | Explicação |
# | :--- | :--- | :--- |
# | 0<br>0 | SIM | 0 está entre -800 e 22, e entre -20 e 35. |
# | -800<br>-20 | SIM | O ponto está exatamente na borda inferior esquerda. |
# | 23<br>10 | NAO | $x$ (23) é maior que o limite direito (22). |
# | 10<br>-21 | NAO | $y$ (-21) é menor que o limite inferior (-20). |
# | 22<br>35 | SIM | O ponto está exatamente na borda superior direita. |

# %%
#[py]#
# %%writefile EP3_8.py
# sua solução

# %%
#[py]#
# !python3 testsuite.py EP3_8.py

# %% [markdown]
# ---
#
# ### EP3_9 📦 Pedidos de Discos Voadores — Manipulação de Dígitos
#
# Nesta atividade, você deve processar um código numérico de identificação logística de uma fábrica de discos voadores. O sistema utiliza um número inteiro de **6 dígitos** no formato $OODDMM$ para identificar a origem, o destino e o modelo.
#
# * Leia **1 número inteiro** de 6 dígitos.
# * Separe o número em três partes:
#     1.  **OO** (2 primeiros dígitos): Código do Planeta de Origem.
#     2.  **DD** (2 dígitos do meio): Código do Planeta de Destino.
#     3.  **MM** (2 últimos dígitos): Código do Modelo.
#
# * Identifique os nomes correspondentes utilizando as tabelas abaixo:
#
# **Tabela de Planetas (Origem e Destino):**
#
# | Código | Planeta |
# | :--- | :--- |
# | 80 | Marte |
# | 81 | Saturno |
# | 90 | Netuno |
# | 91 | HD21749b |
#
# **Tabela de Modelos:**
#
# | Código | Modelo |
# | :--- | :--- |
# | 60 | A6000 |
# | 61 | B7500 |
# | 62 | C9000 |
#
# **Saída:**
# * Imprima o **Nome do Planeta de Origem**.
# * Imprima o **Nome do Planeta de Destino**.
# * Imprima o **Nome do Modelo**.
#
# (Cada um em uma linha separada).
#
# ---
#
# #### 💡 Dica de Implementação
#
# Para extrair os pares de dígitos de um número inteiro $N$ (ex: 809162), você pode utilizar operações de divisão inteira e resto (módulo):
#
# * Para pegar os dois primeiros ($OO$): Divida por 10000.
#     $$OO = N \div 10000$$
# * Para pegar os dois do meio ($DD$): Pegue o resto da divisão por 10000 e divida o resultado por 100.
#     $$DD = (N \pmod{10000}) \div 100$$
# * Para pegar os dois últimos ($MM$): Pegue o resto da divisão por 100.
#     $$MM = N \pmod{100}$$
#
# ---
#
# #### 📌 Exemplos
#
# | Entrada | Saída |
# | :--- | :--- |
# | 809162 | Marte<br>HD21749b<br>C9000 |
# | 819060 | Saturno<br>Netuno<br>A6000 |
# | 918061 | HD21749b<br>Marte<br>B7500 |

# %%
#[py]#
# %%writefile EP3_9.py
# sua solução

# %%
#[py]#
# !python3 testsuite.py EP3_9.py

# %% [markdown]
# ---
#
# ### EP3_10 ✈️ Autonomia do Avião — Lógica e Distância
#
# Nesta atividade, você deve determinar se um avião de carga consegue chegar ao seu destino baseando-se no peso da carga transportada e na distância a ser percorrida.
#
# **1. Determine a Autonomia Base:**
# A autonomia do avião varia de acordo com o peso da carga, conforme a tabela abaixo:
#
# | Peso da Carga (kg) | Autonomia Base (km) |
# | :--- | :--- |
# | Até 50.000 | 18.000 |
# | De 50.001 até 200.000 | 9.000 |
# | De 200.001 até 250.000 | 3.000 |
#
# *Nota: A capacidade máxima é 250.000 kg. Você não precisa tratar valores acima disso.*
#
# **2. Calcule a Distância:**
# O programa recebe as coordenadas de partida ($A_x, A_y$) e de destino ($B_x, B_y$). A distância ($d$) deve ser calculada usando a fórmula da distância Euclidiana:
#
# $$d = \sqrt{(B_x - A_x)^2 + (B_y - A_y)^2}$$
#
# **3. Verifique a Viabilidade (Saída):**
# Além da autonomia base, o avião pode ter um rendimento até **10% superior** dependendo das condições de voo.
# * Imprima a distância calculada formatada com **duas casas decimais**.
# * Na linha seguinte, imprima a classificação:
#     * **SIM**: Se a distância é menor ou igual à autonomia base ($d \le Autonomia$).
#     * **TALVEZ**: Se a distância é maior que a autonomia base, mas está dentro do limite extra de 10% ($Autonomia < d \le Autonomia \times 1.10$).
#     * **NAO**: Se a distância é maior que a autonomia com o adicional de 10% ($d > Autonomia \times 1.10$).
#
# **Entrada:**
# * Peso da Carga (kg)
# * $A_x$ (Coordenada X de partida)
# * $A_y$ (Coordenada Y de partida)
# * $B_x$ (Coordenada X de destino)
# * $B_y$ (Coordenada Y de destino)
#
# **Saída:**
# * Distância (com duas casas decimais).
# * A mensagem `SIM`, `TALVEZ` ou `NAO`.
#
# 📌 **Importante**:
# * **🚫 Sem Acentos:** Utilize `NAO` (sem til).
# * Pode utilizar `import math` (Python) ou `Math.sqrt` (Java) para a raiz quadrada.
#
# ---
#
# #### 📌 Exemplos
#
# | Entrada | Saída | Explicação |
# | :--- | :--- | :--- |
# | 40000<br>0<br>0<br>1000<br>0 | 1000.00<br>SIM | Carga < 50k (Autonomia 18000). Distância 1000 é menor que 18000. |
# | 220000<br>0<br>0<br>3000<br>0 | 3000.00<br>SIM | Carga > 200k (Autonomia 3000). Distância é exatamente o limite. |
# | 220000<br>0<br>0<br>3200<br>0 | 3200.00<br>TALVEZ | Carga > 200k (Autonomia 3000). Distância 3200 é maior que 3000, mas menor que 3300 (3000 + 10%). |
# | 220000<br>0<br>0<br>3500<br>0 | 3500.00<br>NAO | Distância 3500 excede o limite máximo com bônus (3300). |

# %%
#[py]#
# %%writefile EP3_10.py
# sua solução

# %%
#[py]#
# !python3 testsuite.py EP3_10.py
